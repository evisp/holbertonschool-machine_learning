# %% [markdown]
# <img src="../../../figs/holberton_logo.png" alt="logo" width="500"/>

# %% [markdown]
# ## Flip Me Over
#
# Write a function `def matrix_transpose(matrix)`: that returns the transpose of a 2D matrix, matrix:
#
# - You must return a new matrix
# - You can assume that matrix is never empty
# - You can assume all elements in the same dimension are of the same type/shape
#
# ```python
# Function matrix_transpose(matrix):
#     # 1. Get the number of rows and columns in the original matrix
#     rows = length(matrix)
#     cols = length(matrix[0])
#
#     # 2. Create a new matrix for the transpose with dimensions swapped
#     transpose = create_matrix(cols, rows)
#
#     # 3. Iterate through the original matrix and fill in the transpose
#     for i from 0 to rows - 1:
#         for j from 0 to cols - 1:
#             # Transpose the elements
#             transpose[j][i] = matrix[i][j]
#
#     # Return the transposed matrix
#     return transpose
# ```

# %% [markdown]
# ## 4. Line Up
#
# Write a function `def add_arrays(arr1, arr2)`: that adds two arrays element-wise:
#
# - You can assume that `arr1` and `arr2` are lists of ints/floats
# - You must return a new list
# - If `arr1` and `arr2` are not the same shape, return None
#
# ```python
# Function add_arrays(arr1, arr2):
#     # 1. Check if the arrays are of the same length
#
#     # 2. Initialize an empty list for the sum of arrays
#
#     # 3. Iterate through the arrays element-wise and add them
#     for i from 0 to length(arr1) - 1:
#         # 3.1 Add the corresponding elements and append to the sum array
#         sum_element = arr1[i] + arr2[i]
#         append(sum_array, sum_element)
#
#     # 4. Return the new list representing the sum of arrays
#     return sum_array
#
# ```

# %% [markdown]
# ## 5. Across The Planes
#
# Write a function `def add_matrices2D(mat1, mat2)`: that adds two matrices element-wise:
#
# - You can assume that mat1 and mat2 are 2D matrices containing ints/floats
# - You can assume all elements in the same dimension are of the same type/shape
# - You must return a new matrix
# - If mat1 and mat2 are not the same shape, return None
#
# ```python
# Function add_matrices2D(mat1, mat2):
#     # 1. Check if the matrices have the same dimensions
#
#     # 2. Initialize an empty matrix for the sum of matrices
#
#     # 3. Iterate through the rows of matrices
#     for i from 0 to length(mat1) - 1:
#         # 3.1 Initialize an empty row for the result matrix
#         row = []
#
#         # 3.2 Iterate through the elements of each row
#         for j from 0 to length(mat1[0]) - 1:
#             # 3.2.1 Add the corresponding elements and append to the row
#             sum_element = mat1[i][j] + mat2[i][j]
#             append(row, sum_element)
#
#         # 3.3 Append the row to the result matrix
#         append(result, row)
#
#     # 4. Return the new matrix representing the sum of matrices
#     return result
#
# ```
