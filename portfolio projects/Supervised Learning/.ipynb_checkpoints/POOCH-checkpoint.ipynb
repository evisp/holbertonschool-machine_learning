# %% [markdown]
# # Dogs Are nice, right??
#
# - Well you'd better have said yes else i HATE you.
# * Jk, in this notebook we will be researching some dog breeds and classifying them.
#
# - We have roughly 130 classes of different breeds(Some better than others).
#
# We wil be using a built from scratch model so the accuracy will not be amazing or anything of the sorts
#
# ## Still this is mostly an experimental model mostly used for getting comfortable with using:
# * keras models
# * Data Augmentation
# * Normalization of Data
# * Image Dimension Changing (Although Not Implemented Perfectly)
# * Summarization and Validation of the model
# * Improving it with Optimization, Callbacks
# * A general consensus on how Convolutional Neural Networks work..
#
# ***With all the boring stuff gone, Lets Do This!***

# %%
# Acquire the data
train_data = 'images/Images'
annot_data = "annotations/Annotation"

# %% [markdown]
# We have taken two different sets of data, the training data and the annotation data.
# * The training data holds the main Images and classes
# - And the annot data holds the Classifier of each Image.

# %%
# Simpy took the main important libraries needed
import os
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# After importing everything, we have tried to restructure the image sizes, but we seem to have made quite the blunder as,
# the effects of the image reprocessing were not noticable.
#
# **What we have instead done is just leave the image sizes here for later use.**

# %%
# The image sizes to be modified later

breed_list = os.listdir(annot_data)
image_width = 128
image_height = 128
num_channels = 3
num_classes = len(breed_list)

# %% [markdown]
# * Below is the keras dataset import module, which allows us to make a dataset from the images we have
#
# > The training data will be used for the dataset (which as described above, holds the Images)
# - The validation split will be 0.8 for the training data and 0.2 for the validation data.
# * The subset of the train dataset is "training" obviously, and for the validation dataset it is "validation".
# - The seed for the training and validation data have been set for constant accurate results, ***ALSO 42 IS THE MEANING OF LIFE***
# * The image sizes are 128, 128 as set in the above image rescaler. (which doesn't work)

# %%
# Load the training data without preprocessing
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_data,
    validation_split=0.8,
    subset="training",
    seed=123,
    image_size=(128, 128),
    batch_size=32,
)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_data,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(128, 128),
    batch_size=32,
)
# Out:
# Found 20580 files belonging to 120 classes.
# Using 4116 files for training.
# Found 20580 files belonging to 120 classes.
# Using 4116 files for validation.

# %% [markdown]
# Below are all the names of the classes, this actually uses the anot names.

# %%
# Checking the classes

class_names = train_dataset.class_names

num_classes = len(class_names)

for class_name in class_names:
    print(class_name)
# Out:
# n02085620-Chihuahua
# n02085782-Japanese_spaniel
# n02085936-Maltese_dog
# n02086079-Pekinese
# n02086240-Shih-Tzu
# n02086646-Blenheim_spaniel
# n02086910-papillon
# n02087046-toy_terrier
# n02087394-Rhodesian_ridgeback
# n02088094-Afghan_hound
# n02088238-basset
# n02088364-beagle
# n02088466-bloodhound
# n02088632-bluetick
# n02089078-black-and-tan_coonhound
# n02089867-Walker_hound
# n02089973-English_foxhound
# n02090379-redbone
# n02090622-borzoi
# n02090721-Irish_wolfhound
# n02091032-Italian_greyhound
# n02091134-whippet
# n02091244-Ibizan_hound
# n02091467-Norwegian_elkhound
# n02091635-otterhound
# n02091831-Saluki
# n02092002-Scottish_deerhound
# n02092339-Weimaraner
# n02093256-Staffordshire_bullterrier
# n02093428-American_Staffordshire_terrier
# n02093647-Bedlington_terrier
# n02093754-Border_terrier
# n02093859-Kerry_blue_terrier
# n02093991-Irish_terrier
# n02094114-Norfolk_terrier
# n02094258-Norwich_terrier
# n02094433-Yorkshire_terrier
# ...

# %% [markdown]
# Below is a simple representation of the Images and Annotations

# %%
import matplotlib.pyplot as plt

for images, labels in train_dataset.take(1):
    batch_images, batch_labels = images.numpy(), labels.numpy()

plt.figure(figsize=(15, 5))
for i in range(5):
    plt.subplot(2, 5, i+1)
    plt.imshow(batch_images[i].astype('uint8'))
    plt.title(class_names[batch_labels[i]])
    plt.axis('off')
plt.show()

# %% [markdown]
# Below is the Data Augmentation function we will be using.
# - Data augmentation is the process of modifying Images slightly to produce new but similar images, which helps in boosting the amount of available data,  which in term boosts the accuracy of the model.
# - Normalizes the data between 0.0 and 0.255
#
#
# * The rotation range for flipping the image is set to 45 degrees
# - The width_shift_range allows for moving images either vertically or horizontally, the value of 0.2 is applied.
# * Same as above with the height_shift_range except it moves the images vertically, also set to 0.2.
# - Shear is basically making pixels bigger which provides a certain analogue feeling to the image, value is set to 20%
# * Zoom_range is pretty self explanatory, it is set to 0.2.
# - Horizontal_flip just flips images horizontally randomly, it is set to true.
# * fill_mode fills any missing pixels.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rescale=1./255,
    # normalizes the images
    rotation_range=45,
    # Randomly rotate images by up to 45 degrees
    width_shift_range=0.2,
    # Randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,
    # Randomly shift images vertically (fraction of total height)
    shear_range=20,
     # Apply shear transformations
    zoom_range=0.2,
    # Randomly zoom in/out
    horizontal_flip=True,
    # Randomly flip images horizontally
    fill_mode="nearest"
    # Fill missing pixels after transformations
)

# %% [markdown]
# So since we are using the Keras built in datasets, we need to apply data augmentation and normalization a different way.
# - By using the function augment for modifying the images, we can modify the keras dataset.
#
# - The image is firstly divided (/) by 255 which will make the data closer to each other and allow easier data collection and assesement by the model.
#
# - Then we will use the keras version of the methods called in the regular Data augmentation function
#
# So basically, flipping left and right, up and down, image brightness, image saturation, and resizing the images to the widths that we chose in the failed image resizer
#
# ## Being completely honest... No idea if the new sizes work

# %%
def augment(image, label):
    image = image / 255
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_saturation(image, lower=0.5, upper=1.5)
    image = tf.image.resize(image, size=(image_height, image_width))
    return image, label

# %% [markdown]
# Finally after 1000 words we have arrived to the meat and bones of this.
#
# ### The model....
#
# We have made quite the complex piece of technology, trying to top out even BMW.
#
# * Complex doesn't neccesarily mean good though.
#
# We have 5 different Convolution Blocks followed by a Flatten Layer and 4 hidden dense layers.
#
# > * In each of the Convolution Blocks, the spread out of the layers is this:
# >> - 1 Convolution Layer starting at 32 filters and doubled untill 512, with a kernel size of 3, and the HeNormal kernel regularizer in each layer
# >> - 1 batch normalization after each Convolution Layer
# >> - 1 Average Pooling Layer with pool size of 2 and 2 strides using the HeNormal Kernel Init.
# >> - Another Convolution layer with the same parameters as the first one
# >> - An Average Pooling Layer with pool size of 2 and 2 strides using the HeNormal Kernel Init.
# >> - And finally a Dropout layer with 0.2 value applied
#
# This continues for 5 convolution layers, afterwards being Flattened and moving on to the Dense Layers
#
#
# > * Each Dense layer is spread out like this:
# >> * The dense layer starting at 256 and going untill 32
# >> - After each layer 1 Batch normalization and one Dropout layer follows each
# >> - And ending it off is **1** output layer with the softmax function.
#
# #### All layers (except the output) use the relu activation function, and the Convolution layers have a padding of "same".

# %%
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping

# For fitting the model later
early_stopping = EarlyStopping(patience=5, verbose=1, monitor="val_loss", restore_best_weights=True)

# initializer
init = keras.initializers.HeNormal()


# making the model using 3 layers of convolution and pooling and 2 dense
model = keras.Sequential([
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu',
                  padding='same', input_shape=(128, 128, 3),
                  kernel_initializer=init),
    layers.BatchNormalization(),
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu',
                  padding='same', kernel_initializer=init),
    layers.BatchNormalization(),
    layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
    layers.Dropout(0.2),

    layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same',
                  kernel_initializer=init
                  ),
    layers.BatchNormalization(),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu',
                  padding='same', kernel_initializer=init),
    layers.BatchNormalization(),
    layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
    layers.Dropout(0.2),

    layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same',
                  kernel_initializer=init
                  ),
    layers.BatchNormalization(),
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu',
                  padding='same', kernel_initializer=init),
    layers.BatchNormalization(),
    layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
    layers.Dropout(0.2),

    layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same',
                  kernel_initializer=init
                  ),
    layers.BatchNormalization(),
    layers.Conv2D(256, kernel_size=(3, 3), activation='relu',
                  padding='same', kernel_initializer=init),
    layers.BatchNormalization(),
    layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
    layers.Dropout(0.2),

    layers.Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same',
                  kernel_initializer=init
                  ),
    layers.BatchNormalization(),
    layers.Conv2D(512, kernel_size=(3, 3), activation='relu',
                  padding='same', kernel_initializer=init),
    layers.BatchNormalization(),
    layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'),
    layers.Dropout(0.2),

    layers.Flatten(),

    layers.Dense(256, activation='relu', kernel_initializer=init),
    layers.BatchNormalization(),
    layers.Dropout(0.25),

    layers.Dense(128, activation='relu', kernel_initializer=init),
    layers.BatchNormalization(),
    layers.Dropout(0.5),

    layers.Dense(64, activation='relu', kernel_initializer=init),
    layers.BatchNormalization(),
    layers.Dropout(0.5),

    layers.Dense(32, activation='relu', kernel_initializer=init),
    layers.BatchNormalization(),
    layers.Dropout(0.25),

    layers.Dense(num_classes, activation='softmax', kernel_initializer=init)
])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %% [markdown]
# ## After the model is made, now we need to compile it.
#
# We will perform the compilation using the Adam optimizer,
# the sparce_categorical_crossentropy loss function,
# and the accuracy metric

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy']
              )

# %% [markdown]
# ### After compiling it we can summarize it.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ...

# %% [markdown]
# # Thaaaat's a biig boi.
# 6 million parameters is quite chonky, luckily with batch normalization and the whole shabang it is quite trainable
#
# Coming in at only 129 parameters at roughly 650 ms/step training this is not your worst chore.

# %%
# Augment the dataset
augmented_dataset = train_dataset.map(augment)


history = model.fit(augmented_dataset, batch_size=64, epochs=100, validation_data=val_dataset, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 76s 586ms/step - accuracy: 0.0263 - loss: 4.6613 - val_accuracy: 0.0063 - val_loss: 59.4427
# Epoch 2/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 77s 598ms/step - accuracy: 0.0244 - loss: 4.6356 - val_accuracy: 0.0090 - val_loss: 45.1557
# Epoch 3/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 80s 622ms/step - accuracy: 0.0223 - loss: 4.6158 - val_accuracy: 0.0126 - val_loss: 43.4666
# Epoch 4/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 80s 621ms/step - accuracy: 0.0330 - loss: 4.5863 - val_accuracy: 0.0124 - val_loss: 50.0847
# Epoch 5/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 80s 620ms/step - accuracy: 0.0275 - loss: 4.5620 - val_accuracy: 0.0112 - val_loss: 67.8223
# Epoch 6/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 80s 621ms/step - accuracy: 0.0235 - loss: 4.5539 - val_accuracy: 0.0100 - val_loss: 32.6630
# Epoch 7/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 80s 621ms/step - accuracy: 0.0310 - loss: 4.5187 - val_accuracy: 0.0087 - val_loss: 37.2742
# Epoch 8/100
# ...

# %% [markdown]
# # As visible the model isn't too good, as it triggered the early stopping only in its 11th Epoch
#
# > The reason this happens is that whilst we are making many amends to the data and modifying it to make it more accessible, the model is far too unstable and lacks a clear and easy structure for more stable hand-built models.
#
# * Getting 3 Percent on accuracy and 1.7 percent validation accuracy took a very long time and the model had to be changed at least 10-20 times.
#
# - Even then the loss was at 4.47 (in its best), whilst usually staying at 5 - 5.30, same applies with the validation loss which stayed around 40-117.
#
# Very unstable and ineffective.
# If this model was constructed the same way but used a pre-trained model instead, we would be achieving 95-99% accuracy as those models have been tried and tested by the biggest and most prestigious companies in the world.
#
# **The VGG19 model achieves 99% accuracy in just 20 Epochs in this specific project, whilst the best we can do is 3.**

# %%
# visualization of results
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# #### The model doesn't have a bad train loss but is veeeery poor in its validation loss
#
# This shows that this model should be scrapped and maybe one of the way more effective pre-built ones should be used.

# %%
# visualization of accuracy

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# #### Same goes with the accuracy, but this at least is a teeny tiny bit better than the validation accuracy.
#
# Only fractionally unfortunately

# %%
# evaluating this crappy model

test_loss, test_acc = model.evaluate(val_dataset, verbose=2)

print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 129/129 - 25s - 192ms/step - accuracy: 0.0100 - loss: 32.6560
# Test accuracy: 0.009961127303540707
# Test loss: 32.65601348876953

# %% [markdown]
# Better on the loss, but worse on the test

# %% [markdown]
# # That concludes this little test. My pain may now Cease!!
