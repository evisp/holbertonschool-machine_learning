# %%
def apt_growth_value(initial_value, rate, years):
    value = initial_value
    for year in range(years):
        value *= (1 + rate / 100)
    return value

# %%
print(apt_growth_value(100000, 5, 20))
# Out:
# 265329.7705144421
