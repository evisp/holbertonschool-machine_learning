# %% [markdown]
# ## Project Overview
#
# In this project, we will use **unsupervised learning techniques to analyze the Mall Customers dataset**. The main goal is to **uncover hidden patterns in the customer data and segment them into distinct groups based on features such as age, income, and spending habits**. These insights can help businesses tailor marketing strategies and improve customer engagement.
#
# ### Key Objectives
#
# - **Understand the Data**:
#   - Explore the dataset to understand the distribution of customer features.
#   - Identify any data quality issues and perform necessary cleaning.
#
# - **Segment Customers**:
#   - Apply unsupervised learning methods (e.g., clustering algorithms like K-means) to group similar customers.
#   - Discover natural segments that reveal distinct customer behaviors.
#
# - **Visualize and Interpret**:
#   - Use visualizations to illustrate the clusters and their characteristics.
#   - Interpret the results to provide actionable insights for business decisions.
#
# ### Learning Task
#
# - **Type of Learning**:
#   - **Unsupervised Learning** – specifically, clustering techniques will be used since the goal is to discover inherent groupings in the data without pre-labeled outcomes.
#
# ### Overall Approach
#
# 1. **Data Exploration and Preprocessing**:
#    - Load the dataset and perform exploratory data analysis (EDA) to understand its structure.
#    - Clean and preprocess the data, handling missing values and scaling features as needed.
#
# 2. **Clustering Model Development**:
#    - Choose an appropriate clustering algorithm (e.g., K-means).
#    - Determine the optimal number of clusters using methods like the Elbow method or silhouette scores.
#
# 3. **Evaluation and Visualization**:
#    - Evaluate the clustering performance quantitatively and qualitatively.
#    - Visualize the clusters using plots (e.g., scatter plots, PCA projections) to better interpret the results.
#
# 4. **Insight Extraction**:
#    - Analyze the characteristics of each customer segment.
#    - Discuss how these segments can inform targeted marketing strategies and other business actions.
#
# ---

# %% [markdown]
# ### 1: Loading and Inspecting the Data
#
# In this step, we will load the Mall Customers dataset into our Python environment using Pandas. The dataset provides essential information about mall customers such as:
#
# - **CustomerID**: A unique identifier for each customer.
# - **Gender**: The customer's gender.
# - **Age**: The age of the customer.
# - **Annual Income (k$)**: The customer's annual income (in thousands of dollars).
# - **Spending Score (1-100)**: A score assigned to the customer based on their purchasing behavior.
#
# You can download the dataset from [this link](https://gist.github.com/pravalliyaram/5c05f43d2351249927b8a3f3cc3e5ecf).

# %%
import pandas as pd

data = pd.read_csv('mallcustomers.csv')  
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ## 1. Data Description
# The **Mall Customers** dataset contains information about individual customers who visit a mall. The dataset is structured into the following columns:
#
# - **CustomerID**:
#   - A unique numerical identifier assigned to each customer.
#   - Helps to distinguish between different customers in the dataset.
#
# - **Gender**:
#   - Indicates the gender of the customer (e.g., "Male" or "Female").
#   - Useful for demographic analysis and understanding the gender distribution of the customers.
#
# - **Age**:
#   - Represents the age of the customer in years.
#   - Helps in analyzing the age demographics of the mall's clientele.
#
# - **Annual Income**:
#   - Specifies the annual income of the customer in thousands of dollars.
#   - Provides insight into the financial profile of the customers, which can influence spending behavior.
#
# - **Spending Score (1-100)**:
#   - A score assigned based on the customer's purchasing behavior at the mall.
#   - The score ranges from 1 to 100, where a higher score generally indicates a higher propensity to spend.
#   - This metric is useful for segmenting customers and tailoring marketing strategies.
#
# ---
#
# ## 2. Data Inspection
# Before diving into any analysis, it's important to perform an initial inspection of the data. In this step, we will:
#
# - **Check the Shape of the Dataset**:
#   - Determine the number of rows and columns.
#
# - **Review the Data Types and Basic Information**:
#   - Use functions that provide details about each column, such as data type and non-null counts.
#
# - **Display Summary Statistics**:
#   - Get a quick overview of the numerical data (mean, standard deviation, min, max, etc.).
#
# - **Identify Missing Values**:
#   - Check if any columns have missing data that might need to be handled.
#
# - **Check for Duplicates**:
#   - Identify any duplicate rows that might need to be removed before proceeding with er data analysis and model development.
#
# ---
# l development.
#
# ---

# %%
print("Dataset shape:", data.shape)
# Out:
# Dataset shape: (200, 5)

# %%
print("\nData Information:")
data.info()
# Out:
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
print("\nSummary Statistics:")
print(data.describe())
# Out:
# Summary Statistics:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
print("\nMissing Values:")
print(data.isnull().sum())
# Out:
# Missing Values:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
print("\nNumber of Duplicate Rows:")
print(data.duplicated().sum())
# Out:
# Number of Duplicate Rows:
# 0

# %% [markdown]
# ## 2: Exploratory Data Analysis
#
# - **Understand the Distribution of Features**:
#   - Identify the spread, central tendency, and variability of numerical variables such as Age, Annual Income, and Spending Score.
#   - Detect any potential outliers or unusual patterns.
#
# - **Examine Categorical Variables**:
#   - Analyze the distribution of the Gender variable to see the balance between categories.
#
# - **Explore Relationships Between Variables**:
#   - Use scatter plots and pair plots to visualize the relationships among numerical variables. This can help in identifying potential clusters or correlations that might be useful for unsupervised learning.
#
# - **Visualize Data for Clustering Insight**:
#   - Generate visualizations that might hint at underlying groupings, which will be valuable when we later apply clustering techthe data, guiding you on how to approach the next steps in your unsupervised learning project.

# %% [markdown]
# ### Histogram of Age Distribution
#
# This histogram shows the distribution of the "Age" variable among the mall customers. The x-axis represents the customers' ages, and the y-axis indicates the number of customers within each age bin. A Kernel Density Estimate (KDE) line is overlaid to provide a smoothed version of the distribution.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))

sns.histplot(data['Age'], kde=True, bins=20, color='skyblue')

plt.title('Age Distribution of Mall Customers')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ### Count Plot for Gender Distribution
#
# This count plot visualizes the number of mall customers by gender. The x-axis displays the gender categories (`Male` and `Female`), while the y-axis represents the count of customers in each category.
#
# - **Balance of Gender Representation:**
#   The plot helps identify whether there is a balanced distribution between male and female customers or if one gender dominates the dataset.
# - **Implications for Segmentation:**
#   Understanding the gender distribution can be important for targeted marketing strategies and can influence how customer segments are defined.

# %%
plt.figure(figsize=(6, 4))

sns.countplot(x='Gender', data=data, palette='pastel')

plt.title('Gender Distribution of Mall Customers')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()
# Out:
# C:\Users\evisp\AppData\Local\Temp\ipykernel_34912\4068380272.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=data, palette='pastel')

# %% [markdown]
#  3: Scatter Plot of Annual Income vs. Spending Sco:**
# This scatter plot displays the relationship between customers’ annual income (in thousands of dollars) and their spending score (ranging from 1 to 100). Each point in the plot represents an individual customer, with the x-axis showing the annual income and the y-axis showing the spending score. Additionally, the points are colored by gender to help reveal any gender-specific trends or clusters.
#
# **Analysis:**
# - **Cluster Identification:**
#   The scatter plot can reveal natural groupings of customers, which is especially useful for segmentation. For instance, you might observe distinct clusters of high-income/high-spending customers versus low-income/low-spending customers.
#
# - **Relationship Insights:**
#   While a direct correlation between income and spending is not always expected, any visible patterns or groupings can provide valuable insights into different customer behaviors.
#
# - **Implications for Segmentation:**
#   Understanding the spread and relationship between income and spending score will help in tailoring marketing strategies and developing targeted promotions for each iden. clustering techniques to define customer groups.rstanding the customer distribution before moving to clustering. 🚀

# %%
plt.figure(figsize=(8, 6))

# Create the scatter plot for Annual Income vs. Spending Score, with gender differentiation
sns.scatterplot(x='Annual Income (k$)', 
                y='Spending Score (1-100)', 
                data=data, 
                hue='Gender', 
                palette='Set1', 
                s=100, 
                alpha=0.7)

# Add titles and labels
plt.title('Annual Income vs. Spending Score')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend(title='Gender')

# Display the plot
plt.show()

# %% [markdown]
# ###  Box Plot – Spending Score vs. Gender
#
# This box plot compares the **spending scores** of male and female customers. It visualizes the distribution, median, quartiles, and outliers, helping to understand differences in spending behavior between genders.
#
# #### **Analysis:**
# - **Gender Differences:**
#   - If the median spending score is significantly different, one gender may be spending more on average.
# - **Outliers:**
#   - Some customers may have unusually high or low spending scores, indicating extreme behavior.
# - **Spread of Spending:**
#   - A wider spread suggests more varied spending habits within that gender.

# %%
plt.figure(figsize=(6, 6))

sns.boxplot(x='Gender', y='Spending Score (1-100)', data=data, palette='pastel')

plt.title('Box Plot: Spending Score by Gender')
plt.xlabel('Gender')
plt.ylabel('Spending Score (1-100)')

plt.show()
# Out:
# C:\Users\evisp\AppData\Local\Temp\ipykernel_34912\100320880.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender', y='Spending Score (1-100)', data=data, palette='pastel')

# %% [markdown]
# ### Heatmap – Correlation Between Numerical Features**
#
# This heatmap visualizes the correlation between the numerical features in the dataset:
# - **Age**
# - **Annual Income (k$)**
# - **Spending Score (1-100)**
#
# Correlations range from **-1 to 1**:
# - **Positive correlation (+1):** As one variable increases, the other also increases.
# - **Negative correlation (-1):** As one variable increases, the other decreases.
# - **Near zero (0):** No strong relationship.
#
# #### **Analysis:**
# - **Identify Strong Relationships:**
#   - If **Annual Income** and **Spending Score** are correlated, higher-income customers may spend more.
# - **Check for Redundant Variables:**
#   - If two variables are highly correlated, one might be unnecessary for clustering.
# - **Determine Independent Features:**
#   - If features have low correlation, they provide unique information, which is useful for clustering.

# %%
correlation_matrix = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']].corr()

# Set up the plotting area
plt.figure(figsize=(6, 5))

# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Add title
plt.title('Heatmap: Correlation Between Numerical Features')

# Display the plot
plt.show()

# %% [markdown]
# ## 3: Clustering with K-Means
#
# Now that we have explored the data, the next logical step is **clustering**—grouping customers based on similar characteristics. One of the most popular clustering algorithms is **K-Means**, which we will apply to segment mall customers.
#
# ### **What is K-Means?**
# K-Means is an **unsupervised machine learning algorithm** used to partition data into **K distinct groups (clusters)**. It works by:
# 1. **Choosing K cluster centers (centroids)** randomly.
# 2. **Assigning each data point to the nearest centroid** based on distance.
# 3. **Updating the centroids** by computing the average position of all points in each cluster.
# 4. **Repeating steps 2 and 3** until clusters no longer change significantly (convergence).
#
# ### **Why Use K-Means for Mall Customers?**
# - **Uncovers customer segments:**
#   - Groups customers with similar behaviors (e.g., high spenders, budget shoppers).
# - **Helps with targeted marketing:**
#   - Businesses can tailor promotions based on customer types.
# - **Identifies trends and spending patterns:**
#   - Clusters may reveal insights such as **young high spenders** vs. **older conservative shoppers**.
# - **Enhances business strategy:**
#   - Personalized recommendations, loyalty programs, and store layout optimizations can be designed based on cluster insights.
#
# ### **How Will We Apply K-Means Here?**
# We will apply K-Means clustering using customer data, specifically focusing on:
# 1. **Choosing the right features** (e.g., Annual Income, Spending Score) to form meaningful clusters.
# 2. **Determining the optimal number of clusters (K)** using methods like the **Elbow Method**.
# 3. **Applying K-Means and visualizing the clusters** to interpret the results.
#
# ### **Expected Outcome**
# By clustering customers, we aim to create well-defined **customer segments** that businesses can use for better decision-making. These insights will be **data-driven**, allowing for more effective marketing strategies and customer engagement.

# %% [markdown]
# ## K-Means Clustering: Annual Income & Spending Score
#
# #### **Why These Features?**
# We use **Annual Income (k$) and Spending Score (1-100)** because:
# - They capture **spending behavior** and **income level**, which are key for customer segmentation.
# - They naturally form **well-separated clusters**, making visualization easier.
# - These two features are **not highly correlated** (as seen in the heatmap), ensuring meaningful clustering.
#
# ---
#
# ### Determine the Optimal Number of Clusters (Elbow Method)
# Before applying K-Means, we need to determine the best **K (number of clusters)**. The **Elbow Method** helps by:
# 1. Running K-Means for different values of **K**.
# 2. Calculating the **inertia (sum of squared distances from points to their nearest centroid)**.
# 3. Identifying the "elbow point" where the inertia stops decreasing significantly, indicating the optimal **K**.

# %%
from sklearn.cluster import KMeans

X = data[['Annual Income (k$)', 'Spending Score (1-100)']].values

# Using the Elbow Method to find optimal K
inertia = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(6, 4))
plt.plot(K_range, inertia, marker='o', linestyle='--')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal K')
plt.show()
# Out:
# C:\Users\evisp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\evisp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\evisp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %% [markdown]
# ### Apply K-Means with Optimal K & Visualize Clusters
#
# Once the best `K` is found (in our case `k=5``, we:
#
# - Apply K-Means using that value of K.
# - Assign each customer to a cluster.
# - Visualize the clusters in a scatter plot.

# %%
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

# Remove special characters and spaces from column names for easier handling
data.columns = data.columns.str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# Selecting features for clustering
X = data[['Annual_Income_k$', 'Spending_Score_1-100']]

# Applying K-Means with optimal k
optimal_k = 5
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
data['Cluster'] = kmeans.fit_predict(X)

# Scatter plot with bigger figure size
plt.figure(figsize=(10, 8))  # Increase figure size

sns.scatterplot(x='Annual_Income_k$', 
                y='Spending_Score_1-100', 
                hue='Cluster',  # Using cluster numbers as hue
                data=data,      # Pass the data to sns.scatterplot
                palette='Set1', 
                s=100, 
                alpha=0.8)

# Plot cluster centers
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', marker='X', s=200, label='Centroids')

plt.title('K-Means Clustering: Annual Income vs Spending Score', fontsize=16)
plt.xlabel('Annual Income (k$)', fontsize=14)
plt.ylabel('Spending Score (1-100)', fontsize=14)
plt.legend(title='Clusters', fontsize=12)
plt.show()
# Out:
# C:\Users\evisp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ### Analysis
# After running the plot above, here’s what the clusters might represent based on the data:
#
# 1. **Cluster 0: Low Income - Low Spend**
#    - Customers who have low annual income and also low spending scores.
#
# 2. **Cluster 1: Medium Income - High Spend**
#    - Customers who fall in the middle range for income but have high spending scores.
#
# 3. **Cluster 2: High Income - Low Spend**
#    - Customers with high income but relatively low spending scores.
#
# 4. **Cluster 3: Medium Income - Medium Spend**
#    - Customers who have medium income and spend moderately.
#
# 5. **Cluster 4: High Income - High Spend**
#    - Customers with high income and high spending scores.
#
# These clusters can help identify different customer profiles for targeted marketing strategies, product offerings, or service improvements.

# %% [markdown]
# ### **Cluster Validation with Silhouette Score and Agglomerative Clustering**
#
# Cluster validation is essential to assess the quality of the clusters you've created. The **Silhouette Score** can help measure the cohesion and separation of clusters, while **Agglomerative Clustering** can be used as an alternative clustering method to compare results.
#
# #### **1. Silhouette Score**
# The **Silhouette Score** is a metric used to determine how similar an object is to its own cluster compared to other clusters. It ranges from -1 to 1:
# - **1**: Perfect clustering (data points are very similar within their own cluster and dissimilar to other clusters).
# - **0**: Indifferent (data points are on or near the decision boundary between clusters).
# - **-1**: Poor clustering (data points are misclassified).
#
# **Formula:**
# The silhouette score for each point \( i \) is calculated as:
# $$
# S(i) = \frac{b(i) - a(i)}{ \max(a(i), b(i)) }
# $$
# Where:
# - $a(i)$ is the average distance between $i$ and all other points in the same cluster.
# - $b(i)$ is the average distance between $i$ and all points in the nearest cluster.
#
# A **higher Silhouette Score** indicates better-defined and well-separated clusters.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

optimal_k = 5
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
data['Cluster_KMeans'] = kmeans.fit_predict(X)

silhouette_kmeans = silhouette_score(X, data['Cluster_KMeans'])
print(f'Silhouette Score for K-Means: {silhouette_kmeans}')
# Out:
# C:\Users\evisp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Silhouette Score for K-Means: 0.553931997444648

# %% [markdown]
# The Silhouette Score of 0.55 for K-Means indicates that the clusters are moderately well-separated. A score closer to 1 would suggest very distinct clusters, while a score near 0 indicates overlapping clusters. In this case, the score of 0.55 shows that the clustering is decent, but there is still room for improvement in terms of separation between clusters.

# %% [markdown]
# ### Agglomerative Clustering:
#
# Agglomerative Clustering is a type of hierarchical clustering algorithm. Unlike K-Means, which requires the number of clusters to be specified upfront, Agglomerative Clustering builds a hierarchy of clusters by iteratively merging the closest pair of clusters. It’s particularly useful when you don’t know how many clusters you should expect and is better suited for non-spherical cluster shapes. The result is often represented as a dendrogram, which shows the hierarchy of clusters.
#
# Agglomerative Clustering is valuable when you need a hierarchical structure of your data or when you want to explore potential cluster relationships without predefining the number of clusters. It can be used for discovering patterns that K-Means might miss due to its rigid structure of specifying cluster numbers.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage

# Clean column names
data.columns = data.columns.str.replace(' ', '_').str.replace('($)', '').str.replace('[^A-Za-z0-9_]', '', regex=True)

# Select relevant features for clustering
X = data[['Annual_Income_k', 'Spending_Score_1100']]

# Standardize the data before clustering (important for distance-based algorithms)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform hierarchical/agglomerative clustering using 'ward' method
Z = linkage(X_scaled, method='ward')

# Plot the dendrogram with different colors for clusters, and hide x-axis labels
plt.figure(figsize=(12, 8))
dendrogram(Z, labels=data['CustomerID'].values, orientation='top', color_threshold=5)

# Hide x-axis labels
plt.xticks([])

plt.title('Dendrogram for Agglomerative Clustering')
plt.xlabel('Customer ID')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ### Project Summary: Customer Segmentation Using Clustering
#
# This project applied clustering techniques to segment customers based on annual income and spending score, aiming to uncover distinct customer groups for targeted marketing.
#
# #### Key Achievements:
# 1. **Data Preprocessing:** Cleaned and standardized data for accurate analysis.
# 2. **K-Means Clustering:** Created 5 customer segments and validated the clustering with a Silhouette Score.
# 3. **Agglomerative Clustering:** Used hierarchical clustering to confirm segment consistency, visualized with a dendrogram.
# 4. **Cluster Visualization:** Differentiated clusters through color-coded scatter plots for easy interpretation.
#
# #### Business Impact:
# - **Targeted Marketing:** Identified segments for personalized marketing strategies.
# - **Resource Allocation:** Enabled efficient resource distribution toward high-value groups.
# - **Informed Strategy:** Provided actionable insights for product, promotion, and customer service decisions.
#
# The project showcases the power of clustering techniques in driving data-driven business decisions.
